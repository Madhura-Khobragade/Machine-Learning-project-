# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('onlinefraud.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3ceee29bfe44> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 data = pd.read_csv('onlinefraud.csv')
#       6 data.head()
#
# ...

# %%
data.isnull().sum() # counting all null / missing values from the data
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
data.type.value_counts() # counting the number of each type . types of transactions
# Out:
# type
# CASH_OUT    331405
# PAYMENT     300201
# CASH_IN     200470
# TRANSFER     75476
# DEBIT         5899
# Name: count, dtype: int64

# %%
data.isFraud.value_counts()
# Out:
# isFraud
# 0.0    912950
# 1.0       500
# Name: count, dtype: int64

# %%
# to see recuring transaction
type = data['type']. value_counts()
transactions = type.index
quantity = type.values

import plotly.express as px
figure = px.pie(data,
             values=quantity,
             names=transactions,hole = 0.5,
             title="Distribution of Transaction Type")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Select only numeric columns before calculating correlation
numeric_data = data.select_dtypes(include=['number'])
correlation = numeric_data.corr()
print(correlation['isFraud'].sort_values(ascending=False))
# Out:
# isFraud           1.000000
# amount            0.072784
# oldbalanceOrg     0.000868
# newbalanceDest   -0.000740
# step             -0.002371
# oldbalanceDest   -0.004918
# newbalanceOrig   -0.006747
# isFlaggedFraud         NaN
# Name: isFraud, dtype: float64

# %%
data['type'] = data['type'].map({'CASH_OUT': 1, 'PAYMENT': 2, 'CASH_IN': 3, 'TRANSFER': 4, 'DEBIT': 5})
data['isFraud'] = data['isFraud'].map({0: 'No Fraud', 1: 'Fraud'})
data.head()
# Out:
#    step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1     2   9839.64  C1231006815       170136.0       160296.36
# 1     1     2   1864.28  C1666544295        21249.0        19384.72
# 2     1     4    181.00  C1305486145          181.0            0.00
# 3     1     1    181.00   C840083671          181.0            0.00
# 4     1     2  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0  No Fraud             0.0
# 1  M2044282225             0.0             0.0  No Fraud             0.0
# 2   C553264065             0.0             0.0     Fraud             0.0
# 3    C38997010         21182.0             0.0     Fraud             0.0
# 4  M1230701703             0.0             0.0  No Fraud             0.0

# %%
#splitting the data
from sklearn.model_selection import train_test_split
x = np.array(data[['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig']])
y = np.array(data[['isFraud']])

# %%
#tranining the machine learning model
from sklearn.tree import DecisionTreeClassifier
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.10, random_state=42)
model = DecisionTreeClassifier()

# Convert ytrain and ytest back to numeric if they are strings
if ytrain.dtype == 'object':
    ytrain = np.where(ytrain == 'Fraud', 1, 0) # Use np.where to convert strings to 0 and 1
if ytest.dtype == 'object':
    ytest = np.where(ytest == 'Fraud', 1, 0)

model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.9996277888468023

# %%
#prediction
#features = [type, amount, oldbalanceorg, newbalanceorgi]
features = np.array([[4, 9000.60, 9000.60, 0.0]])
print(model.predict(features))
#prediction_proba = model.predict_proba(features)
#print(prediction_proba)
# Out:
# [1]
